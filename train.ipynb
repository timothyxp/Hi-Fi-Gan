# %% [markdown]
# # Installation

# %%
# !pip install torch

# %%
# !wget https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# !tar -xjf LJSpeech-1.1.tar.bz2
# Out:
# --2021-11-28 14:22:21--  https://data.keithito.com/data/speech/LJSpeech-1.1.tar.bz2
# Resolving data.keithito.com (data.keithito.com)... 174.138.79.61
# Connecting to data.keithito.com (data.keithito.com)|174.138.79.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2748572632 (2.6G) [application/octet-stream]
# Saving to: ‘LJSpeech-1.1.tar.bz2’
#
# LJSpeech-1.1.tar.bz 100%[===================>]   2.56G  43.3MB/s    in 62s
#
# 2021-11-28 14:23:23 (42.4 MB/s) - ‘LJSpeech-1.1.tar.bz2’ saved [2748572632/2748572632]

# %%
# %%bash
# pip install googledrivedownloader
# pip install wandb
# Out:
# Requirement already satisfied: googledrivedownloader in /opt/conda/lib/python3.7/site-packages (0.4)
# Collecting wandb
#   Downloading wandb-0.12.7-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 2.3 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (2.25.1)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (5.8.0)
# Collecting subprocess32>=3.5.3
#   Downloading subprocess32-3.5.4.tar.gz (97 kB)
#      |████████████████████████████████| 97 kB 10.0 MB/s eta 0:00:01
# Collecting promise<3,>=2.0
#   Downloading promise-2.3.tar.gz (19 kB)
# Requirement already satisfied: six>=1.13.0 in /opt/conda/lib/python3.7/site-packages (from wandb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from wandb) (2.8.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.0-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 34.7 MB/s eta 0:00:01
# Collecting Click!=8.0.0,>=7.0
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 10.1 MB/s eta 0:00:01
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 30.1 MB/s eta 0:00:01
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting configparser>=3.8.1
#   Downloading configparser-5.1.0-py3-none-any.whl (19 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.24-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 46.1 MB/s eta 0:00:01
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.7/site-packages (from wandb) (5.4.1)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from Click!=8.0.0,>=7.0->wandb) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.7/site-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 3.0 MB/s  eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3,>=2.0.0->wandb) (1.26.6)
# Collecting termcolor<2.0.0,>=1.1.0
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->Click!=8.0.0,>=7.0->wandb) (3.6.0)
# Building wheels for collected packages: promise, subprocess32, termcolor, pathtools
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21502 sha256=fb31f9f0266bb640f44c4f7311c4750cb62fa1ad983f90e298373ac697d6d49d
#   Stored in directory: /root/.cache/pip/wheels/29/93/c6/762e359f8cb6a5b69c72235d798804cae523bbe41c2aa8333d
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-py3-none-any.whl size=6502 sha256=bbe97ce9f39496c3163463e66140d6122bb6db6fadf9e513eb78cef3431fdd24
#   Stored in directory: /root/.cache/pip/wheels/50/ca/fa/8fca8d246e64f19488d07567547ddec8eb084e8c0d7a59226a
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4847 sha256=e5e14925d19590bb94f7ef07b4732edb0280c4013857cee8c2a8b317f7075f44
#   Stored in directory: /root/.cache/pip/wheels/3f/e3/ec/8a8336ff196023622fbcb36de0c5a5c218cbb24111d1d4c7f2
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=869ecd0b9eb2c83e040c6458560a8cdd088297fc045c90cdd4b6d961827aa8bb
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built promise subprocess32 termcolor pathtools
# Installing collected packages: smmap, termcolor, gitdb, yaspin, subprocess32, shortuuid, sentry-sdk, protobuf, promise, pathtools, GitPython, docker-pycreds, configparser, Click, wandb
# Successfully installed Click-8.0.3 GitPython-3.1.24 configparser-5.1.0 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 promise-2.3 protobuf-3.19.1 sentry-sdk-1.5.0 shortuuid-1.0.8 smmap-5.0.0 subprocess32-3.5.4 termcolor-1.1.0 wandb-0.12.7 yaspin-2.1.0

# %% [markdown]
# # Imports

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from tts.collate_fn import Batch, LJSpeechCollator
from tts.datasets.utils import get_data_loader
from tts.datasets.ljspeech import LJSpeechDataset
from tts.melspec import MelSpectrogram, MelSpectrogramConfig
from tts.loss.reconstruction import WaveFormReconstructionLoss
from tts.loss.hi_fi_gan import HiFiGANLoss
from tts.model.generator import Generator
from tts.logger.wandb import WanDBWriter
from tts.trainer.simple_trainer import train_epoch, gan_train_epoch, evaluate
from tts.model.discriminator import Discriminator
from tts.config import Config
from tts.utils.util import count_parameters, set_random_seed, set_require_grad, inf_loop
from torch.utils.data import random_split

set_random_seed(42)

config = Config(
    batch_size=4,
    n_channels=128,
    device = 'cuda:0',
)
config.lr = 1e-3

# %%
from itertools import islice, repeat
from torch.utils.data import DataLoader
import sys

import matplotlib.pyplot as plt
from IPython import display
import wandb
import torch
from torch import nn
from torch.optim import Adam
from torch.optim.lr_scheduler import OneCycleLR
from dataclasses import asdict

# %%
dataset = LJSpeechDataset('../FastSpeech/')
mel_config = MelSpectrogramConfig()
featurizer = MelSpectrogram(mel_config).to(config.device)

test_size = int(len(dataset) * config.test_size)
train_size = len(dataset) - test_size

train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

train_loader = get_data_loader(config, train_dataset, LJSpeechCollator())
val_loader = get_data_loader(config, test_dataset, LJSpeechCollator(), mode='val')

model = Generator(config)
discriminator = Discriminator(config)

model = model.to(config.device)
discriminator = discriminator.to(config.device)

loss = WaveFormReconstructionLoss(featurizer, mel_config.pad_value)
#loss = HiFiGANLoss(config)

opt_G = Adam(model.parameters(), lr=config['lr'])

scheduler_G = OneCycleLR(opt_G, **{
    "steps_per_epoch": len(train_loader),
    "epochs": config.n_epochs,
    "anneal_strategy": "cos",
    "max_lr": config.lr * 2,
    "pct_start": 0.1
})

opt_D = Adam(discriminator.parameters(), lr=config['lr'])

scheduler_D = OneCycleLR(opt_D, **{
    "steps_per_epoch": len(train_loader),
    "epochs": config.n_epochs,
    "anneal_strategy": "cos",
    "max_lr": config.lr * 2,
    "pct_start": 0.1
})

# %%
logger = WanDBWriter(config)
# Out:
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# Finishing last run (ID:22vyfei1) before initializing another...
# <br/>Waiting for W&B process to finish, PID 17235... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value=' 0.00MB of 0.00MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col">
# <h3>Run history:</h3><br/><table class="wandb"><tr><td>train/steps_per_sec</td><td>▁</td></tr></table><br/></div><div class="wandb-col">
# <h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/steps_per_sec</td><td>0.0507</td></tr></table>
# </div></div>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# <br/>Synced <strong style="color:#cdcd00">fiery-bee-41</strong>: <a href="https://wandb.ai/timothyxp/Hi-Fi-GAN/runs/22vyfei1" target="_blank">https://wandb.ai/timothyxp/Hi-Fi-GAN/runs/22vyfei1</a><br/>
# Find logs at: <code>./wandb/run-20211215_225355-22vyfei1/logs</code><br/>
# Successfully finished last run (ID:22vyfei1). Initializing new run:<br/>
#                     Syncing run <strong><a href="https://wandb.ai/timothyxp/Hi-Fi-GAN/runs/2dgqxkhm" target="_blank">golden-frog-42</a></strong> to <a href="https://wandb.ai/timothyxp/Hi-Fi-GAN" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
for name, module in model.named_modules():
    if type(module) is nn.Conv1d or type(module) is nn.Conv2d:
        with torch.no_grad():
            module.weight.normal_(0, 0.01)

# %%
# batch = next(iter(train_loader))
# batch = batch.to(config['device'])
# batch.melspec = featurizer(batch.waveform)
# batch = model(batch)
# set_require_grad(discriminator, True)
# set_require_grad(model, False)

# for i in range(10_000):
#     gt, gf = loss(batch, discriminator.mpd, discriminator.mcd)
#     l = gt + gf
    
#     l.backward()
#     print(l.item())
    
#     opt_D.step()

# %%
if config.overfit_batch:
    train_loader = iter(train_loader)
    batch = next(train_loader)
    train_loader = repeat(batch)
    # train_loader = inf_loop(train_loader)

# %%
checkpoint = torch.load("model_epoch=9")
model.load_state_dict(checkpoint['model'])
discriminator.load_state_dict(checkpoint['discriminator'])
opt_G.load_state_dict(checkpoint['optimizer'])
opt_D.load_state_dict(checkpoint['optimizer_D'])

# %%
logger.set_step(32_743)

# %%
for i in range(config.n_epochs):
    train_epoch(
        model, opt_G, train_loader, loss, config, featurizer, logger=logger
    )
    
    evaluate(model, val_loader, config, loss.waveform_loss, featurizer, logger=logger)
    
    if i % 3 == 0:
        torch.save({
            "model": model.state_dict(),
            "optimizer": opt_G.state_dict(),
            "discriminator": discriminator.state_dict(),
            "optimizer_D": opt_D.state_dict()
        }, f"model_epoch={i}")
# Out:
# 0it [00:00, ?it/s]
# /workspace/Hi-Fi-Gan/tts/trainer/simple_trainer.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(20, 5))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_17158/323689813.py in <module>
#       1 for i in range(config.n_epochs):
#       2     train_epoch(
# ----> 3         model, opt_G, train_loader, loss, config, featurizer, logger=logger
#       4     )
#       5
#
# /workspace/Hi-Fi-Gan/tts/trainer/simple_trainer.py in train_epoch(model, optimizer, loader, loss_fn, config, featurizer, logger, scheduler)
#      48
#      49         loss.backward()
# ---> 50         optimizer.step()
#      51
#      52         np_loss = loss.detach().cpu().numpy()
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /opt/conda/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     142                    lr=group['lr'],
#     143                    weight_decay=group['weight_decay'],
# --> 144                    eps=group['eps'])
#     145         return loss
#
# /opt/conda/lib/python3.7/site-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      96         step_size = lr / bias_correction1
#      97
# ---> 98         param.addcdiv_(exp_avg, denom, value=-step_size)
#      99
#     100
#
# KeyboardInterrupt:

# %%
import io

import matplotlib.pyplot as plt
from PIL import Image


def plot_spectrogram_to_buf(spectrogram_tensor, name=None):
    plt.figure(figsize=(20, 5))
    plt.imshow(spectrogram_tensor)
    plt.title(name)
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    buf.seek(0)
    return buf

# %%
Image.open(plot_spectrogram_to_buf(batch.melspec[1].detach().cpu()));

# %%
melspec_prediction = featurizer(batch.waveform_prediction)

# %%
Image.open(plot_spectrogram_to_buf(melspec_prediction[1].detach().cpu()));

# %%
batch = model(batch)

# %%
display.display(display.Audio(batch.waveform_prediction[1].detach().cpu().numpy(), rate=22050))
display.display(display.Audio(batch.waveform[1].cpu().numpy(), rate=22050))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
for i in range(config.n_epochs):
    gan_train_epoch(
        model, discriminator, opt_G, opt_D, train_loader, loss, config, featurizer,
        scheduler_G=scheduler_G, scheduler_D=scheduler_D, logger=logger
    )
    
    evaluate(model, val_loader, config, loss.waveform_loss, featurizer, logger=logger)
    
    if i % 3 == 0:
        torch.save({
            "model": model.state_dict(),
            "optimizer": opt_G.state_dict(),
            "discriminator": discriminator.state_dict(),
            "optimizer_D": opt_D.state_dict()
        }, f"model_epoch={i}")
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2196/1553173809.py in <module>
#       2     gan_train_epoch(
#       3         model, discriminator, opt_G, opt_D, train_loader, loss, config, featurizer,
# ----> 4         scheduler_G=scheduler_G, scheduler_D=scheduler_D, logger=logger
#       5     )
#       6
#
# /workspace/Hi-Fi-Gan/tts/trainer/simple_trainer.py in gan_train_epoch(G, D, optimizer_G, optimizer_D, loader, loss_fn, config, featurizer, scheduler_G, scheduler_D, logger)
#      89             return loss
#      90
# ---> 91         loss = d_step(batch)
#      92
#      93         if config.get('discriminator_backprop_threshold') is not None:
#
# /workspace/Hi-Fi-Gan/tts/trainer/simple_trainer.py in d_step(batch)
#      71             optimizer_D.zero_grad()
#      72
# ---> 73             fake_loss, true_loss = loss_fn(batch, D.mpd, D.mcd, generator_step=False)
#      74             loss = fake_loss + true_loss
#      75
#
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# TypeError: forward() got an unexpected keyword argument 'generator_step'

# %%
batch = next(train_loader)

# %%
batch = batch.to('cuda:0')

# %%
batch = model(batch)

# %%
display.display(display.Audio(batch.waveform_prediction[0].detach().cpu().numpy(), rate=22050))
display.display(display.Audio(batch.waveform[0].cpu().numpy(), rate=22050))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
batch.waveform.shape, batch.waveform_prediction.shape
# Out:
# (torch.Size([1, 162973]), torch.Size([1, 163366]))

# %% [markdown]
# # Eval

# %%
torch

# %%
torch.save(model.state_dict(), "overfitted_model.pth")

# %%
reconstructed_wav = vocoder.inference(batch.melspec_prediction[0:1].transpose(-1, -2)).cpu()

plt.plot(reconstructed_wav.squeeze(), label='reconstructed', alpha=.5)
# plt.grid()
# plt.legend()
plt.show()

# %%
display.display(display.Audio(reconstructed_wav, rate=22050))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
reconstructed_wav = vocoder.inference(batch.melspec_prediction[0:1].transpose(-1, -2)).cpu()
waveform = vocoder.inference(batch.melspec[0:1]).cpu()

plt.plot(reconstructed_wav.squeeze(), label='reconstructed', alpha=.5)
plt.plot(waveform.squeeze(), label='GT', alpha=.5)
# plt.grid()
# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2094/194229760.py in <module>
#       1 reconstructed_wav = vocoder.inference(batch.melspec_prediction[0:1].transpose(-1, -2)).cpu()
# ----> 2 waveform = vocoder.inference(batch.melspec[0:1]).cpu()
#       3
#       4 plt.plot(reconstructed_wav.squeeze(), label='reconstructed', alpha=.5)
#       5 plt.plot(waveform.squeeze(), label='GT', alpha=.5)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
display.display(display.Audio(reconstructed_wav, rate=22050))
display.display(display.Audio(waveform, rate=22050))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
index = 0

waveform = dummy_batch.waveform[index][:dummy_batch.waveforn_length[index]]
durations = dummy_batch.durations[index][:dummy_batch.token_lengths[index]]

# scale by waveform domain
durations = durations * dummy_batch.waveforn_length[index]
durations = durations.cumsum(dim=0).int()

print(dummy_batch.transcript[index])
left = 0
for right, char in zip(durations[:10], dummy_batch.transcript[index]):
    print(char)
    display.display(display.Audio(waveform[left:right], rate=22050))
    left = right
    print('-' * 99)
# Out:
# Printing, in the only sense with which we are at present concerned, differs from most if not from all the arts and crafts represented in the Exhibition
# P
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# r
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# i
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# n
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# t
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# i
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# n
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# g
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
# ,
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# ---------------------------------------------------------------------------------------------------
